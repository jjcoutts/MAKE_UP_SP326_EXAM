# %% [markdown]
# # SDSB326 Exam
#
# This midterm is meant to cover everything from the Python review through web scraping. Questions will vary in their complexity and depth; each question will tell you how many points it is worth. If you are struggling with a question, skip it and move on to the next one. You can always come back to it later. For reading the instructions, you get a bonus. At the bottom of the document, create a Markdown cell and put what your favorite class is this semester. You won't get more points for putting this SDSB326. Breathe! You will be fine. :)
#
# Answer each questions in the space provided. You have until the end of class to submit the document as an HTML on ELMS. **Be sure to include any code in a CODE cell AND written responses or interpretations in a MARKDOWN cell when appropriate.**

# %%
# helping you out - let's load all the packages you will need for this exam
from requests import get
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# ## Question 0 (0pts)
#
# I understand this is an open book and open note exam, but not open Internet, AI, or person. I pledge on my honor that I have not given or received any unauthorized assistance on this assessment.

# %% [markdown]
# ### Answer

# %% [markdown]
# ## Question 1 (2pts)
#
# Running the code below gives me an error message. What's wrong with it? Is there any way to fix it in *in base Python*?
#
# If so, fix the code so that it runs, but make sure the end data structure is the same as the start. (No, you cannot just create a new object from scratch.)

# %% [markdown]
# ``` python
#     some_nums = {5,6,7,8}
#     some_nums[3] = 0
# ```

# %% [markdown]
# ### Answer

# %% [markdown]
# ## Question 2 (5pts)
# Laughter is the best medicine, especially during an exam. Let's take a look at the random joke API (URL: 'http://www.official-joke-api.appspot.com/random_joke').
#
# This question has three parts:
#
# a.) Send a request to the jokes API and check to make sure the request was successful. What code do we look for?
#
# b.) Print the result of the call. What is the setup to your joke? Is it funny?
#
# c.) Create a list of three setups using a *while loop*. (Note: You shouldn't need to use a rest call here since we're only looking at three jokes.)

# %% [markdown]
# ### Answer

# %% [markdown]
# ## Question 3 (4pts)
#
# The US Census Bereau tracks annual population estimates across all 50 states. We have access to a dataset that comes from state population estimates from the Census in 2023 (e.g., assessing population growth post pandemic). In the dataset `state_populations.csv`, population change is tracked in thousands. A figure like "G+173" indicates an increase of 178,000 over 2022. A figure like "L+10" indiciates a *loss* of 10,000 residents.
#
# Write a **loop or list comprehension** that converts the `Population_Trend` variable in the dataset to numeric values and exact values. **States that gained population should have a positive numeric value, and states that lost population should have a negative numeric value.** So, "G+173" should become 173000 and "L+201" should become -201000. Create a new column in `state_populations` called `pop_trend_numeric` that holds the numeric values you created.

# %%
state_populations = pd.read_csv("state_populations.csv")
state_populations.head()
# Out:
#   STATE Region Population_Trend
# 0    TX  South            G+473
# 1    FL  South            G+365
# 2    NC  South            G+140
# 3    GA  South            G+116
# 4    SC  South             G+90

# %% [markdown]
# ### Answer

# %% [markdown]
# ## Question 4 (4pts)
#
# The `pres_2024.csv` data set contains the % vote share for Donald Trump (the Republican candidate) in the 2024 presidential election for each state. Join `pres_2024.csv` with the `state_populations` data set you manipulated for question 2. Use a left join with populations on the left and pres_2024 on the right. Create a scatter plot to show the relationship between `pop_trend_numeric` and `percent_trump2024` in each state. Briefly describe your results.

# %%
pres_2024 = ... # read in the data
pres_2024.head()
# Out:
#   state_abb  percent_trump2024
# 0        AL          64.572092
# 1        AK          54.544809
# 2        AZ          52.217048
# 3        AR          64.196872
# 4        CA          38.332902

# %% [markdown]
# ### Answer

# %% [markdown]
# ## Question 5 (4pts)
#
# The code below grabs some data about the 2025 Nobel Peace Prize. Take a minute to examine the response. How would I access the english language description of the `motivation`? Hint: Think not only about the named layers, but the position within the layers.

# %%
prize_data = get('https://raw.githubusercontent.com/Neilblund/APAN/refs/heads/main/prize.json').json()

prize_data
# Out:
# [{'awardYear': '2025',
#   'category': {'en': 'Peace', 'no': 'Fred', 'se': 'Fred'},
#   'categoryFullName': {'en': 'The Nobel Peace Prize',
#    'no': 'Nobels fredspris',
#    'se': 'Nobels fredspris'},
#   'dateAwarded': '2025-10-10',
#   'prizeAmount': 11000000,
#   'prizeAmountAdjusted': 11000000,
#   'links': {'rel': 'nobelPrize',
#    'href': 'https://api.nobelprize.org/2/nobelPrize/pea/2025',
#    'action': 'Get',
#    'types': 'application/json'},
#   'laureates': [{'id': '1057',
#     'knownName': {'en': 'Maria Corina Machado'},
#     'fullName': {'en': 'Maria Corina Machado'},
#     'portion': '1',
#     'sortOrder': '1',
#     'motivation': {'en': 'for her tireless work promoting democratic rights for the people of Venezuela and for her struggle to achieve a just and peaceful transition from dictatorship to democracy',
# ...

# %% [markdown]
# ### Answer

# %% [markdown]
# ## Question 6 (2pts)
#
# Use the URL below and visit the Books to Scrape website. Use the inspect element on your web browser and get familiar with the HTML structure.

# %%
book_url = 'http://books.toscrape.com/'

# %% [markdown]
# ![books.png](attachment:e0756482-3af8-48d1-90ae-021f4ef878cb.png)

# %% [markdown]
# What is the `html tag` and `class` of the rating for *Tipping the Velvet*?

# %% [raw]
# NOTE: Submit this as a RAW CELL (e.g., <p class = "..."> or <div class = "..."> or put the HTML information in quotation marks or else it will be rendered in the output.

# %% [markdown]
# ### Answer

# %% [markdown]
# ## Question 7 (4pts)
#
# Create a data frame containing the price of each book IN FLOAT FORMAT in dollars. You will need to first do a conversion on the prices since they contain a currency symbol. You will then multiply the total by 1.17 to get the price in dollars.

# %% [markdown]
# ### Answer

# %% [markdown]
# ## Question 8 (4pts)
#
# The `gtd` data set below contains the following variables:
#
# | Variable          | Description                                                                                                                                                  |
# |-------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | country           | Country name                                                                                                                                                 |
# | democracy_score   | 2020 liberal democracy score from the V-DEM project. Higher values indicate a higher level of democracy. Lower values mean less democratic.                  |
# | oil               | ="oil production" if a country was an oil producer in 2020, = "no oil" if a country was not an oil producer in 2020                                          |
# | terrorist_attacks | ="terrorist attack" if a country experienced a terrorist attack in 2020,  ="no terrorist attacks" if a country did not experience a terrorist attack in 2020 |

# %%
gtd = pd.read_csv("fq_data.csv")
gtd.head()
# Out:
#        country  democracy_score             oil  terrorist_attacks
# 0  Afghanistan            0.197  oil production  terrorist attacks
# 1      Albania            0.417  oil production  terrorist attacks
# 2      Algeria            0.152  oil production  terrorist attacks
# 3       Angola            0.177  oil production  terrorist attacks
# 4    Argentina            0.667  oil production  terrorist attacks

# %% [markdown]
# In addition to making countries less stable, many social scientists argue that oil production makes countries less democratic. Produce a **boxplot** that shows the relationship between oil production and the level of democracy in a country. Briefly discuss your results and whether they appear consistent with this expectation.

# %% [markdown]
# ### Answer

# %% [markdown]
# ## The end

# %% [markdown]
# Please render the exam and submit it to the portal on ELMS. :)
